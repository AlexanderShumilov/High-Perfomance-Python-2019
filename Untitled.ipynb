# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib auto
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# Good old paper: https://www.stat.berkeley.edu/~aldous/157/Papers/Schelling_Seg_Models.pdf

# %%
def neighbors_1(pos, i, j): # Pretty easy intuitive model for all 8 neigbours
    n = 0
    
    if pos[(i - 1) % pos.shape[0], j] == 1: # left
        n+=1
    if pos[i, (j - 1) % pos.shape[1]] == 1: # down
        n+=1
    if pos[(i - 1) % pos.shape[0], (j - 1) % pos.shape[1]] == 1: # down-left
        n+=1
    if pos[(i - 1) % pos.shape[0], (j + 1) % pos.shape[1]] == 1: # up-left
        n+=1

    if pos[i, (j + 1) % pos.shape[1]] == 1: # up
        n+=1
    if pos[(i + 1) % pos.shape[0], j] == 1: # right
        n+=1
    if pos[(i + 1) % pos.shape[0], (j - 1) % pos.shape[1]] == 1: # down-right
        n+=1
    if pos[(i + 1) % pos.shape[0], (j + 1) % pos.shape[1]] == 1: # up-right
        n+=1
        
    return n


def unhappy_agents_1(pos, R):
    mov = np.zeros((pos.shape[0], pos.shape[1]))
    for i in range(pos.shape[0]):
        for j in range(pos.shape[1]):
            if neighbors_1(pos, i, j) < R and pos[i, j] == 1:
                mov[i, j] = 1

    return mov


def neighbors_0(pos, i, j): # Pretty easy intuitive model for all 8 neigbours
    n = 0
    
    if pos[(i - 1) % pos.shape[0], j] == 0: # left
        n+=1
    if pos[i, (j - 1) % pos.shape[1]] == 0: # down
        n+=1
    if pos[(i - 1) % pos.shape[0], (j - 1) % pos.shape[1]] == 0: # down-left
        n+=1
    if pos[(i - 1) % pos.shape[0], (j + 1) % pos.shape[1]] == 0: # up-left
        n+=1

    if pos[i, (j + 1) % pos.shape[1]] == 0: # up
        n+=1
    if pos[(i + 1) % pos.shape[0], j] == 0: # right
        n+=1
    if pos[(i + 1) % pos.shape[0], (j - 1) % pos.shape[1]] == 0: # down-right
        n+=1
    if pos[(i + 1) % pos.shape[0], (j + 1) % pos.shape[1]] == 0: # up-right
        n+=1
        
    return n


def unhappy_agents_0(pos, R):
    mov = np.zeros((pos.shape[0], pos.shape[1]))
    for i in range(pos.shape[0]):
        for j in range(pos.shape[1]):
            if neighbors_0(pos, i, j) < R and pos[i, j] == 0:
                mov[i, j] = 1

    return mov

# %%
N = 150
Range = 100 # How many rounds do we have
k = 0
Rs = [i/8 for i in range(9)]
ratio = 0.5 # Let ratio of black/white houses be "ratio" - should be not that big (or for relatively small R all 
            # black houses will be satisfied with their positions). Default - 0.5
N_moving = np.zeros((Range,9))

# %%
R_factor = int(Rs[4]*8) # Number of neighbours to be unhappy enough to move
pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov_1 = np.zeros((N, N))
mov_0 = np.zeros((N, N))
pos_array = []
mov_0_array = []
mov_1_array = []

for p in range(Range):
    mov_1 = unhappy_agents_1(pos, R_factor)
    mov_0 = unhappy_agents_0(pos, R_factor)
    pos_array.append(pos.copy())
    mov_0_array.append(mov_0.copy())
    mov_1_array.append(mov_1.copy())
    
    
    for i in range(mov_1.shape[0]):
        for j in range(mov_1.shape[1]):
            if mov_1[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0
            if mov_0[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 1
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 1:
                        k = 1       
                pos[i_, j_] = 0
                k = 0

# %%
# %matplotlib auto
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

#ani.save('City map for R = %d.gif' % R_factor)
# Out:
# Using matplotlib backend: Qt5Agg

# %%
R_factor = int(Rs[1]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-3041eae8ad4a> in <module>
#      11
#      12 for p in range(Range):
# ---> 13     mov = unhappy_agents(pos, R_factor)
#      14     pos_array.append(pos.copy())
#      15     mov_array.append(mov.copy())
#
# <ipython-input-30-669808ff13bf> in unhappy_agents(pos, R)
#      27     for i in range(pos.shape[0]):
#      28         for j in range(pos.shape[1]):
# ---> 29             if neighbors_1(pos, i, j) < R and pos[i, j] == 1:
#      30                 swap = mov[i,j]
#      31                 mov[i, j] = mov[j,i]
#
# <ipython-input-36-d13a03a068af> in neighbors_1(pos, i, j)
#      15     if pos[(i + 1) % pos.shape[0], j] == 1: # right
#      16         n+=1
# ---> 17     if pos[(i + 1) % pos.shape[0], (j - 1) % pos.shape[1]] == 1: # down-right
#      18         n+=1
#      19     if pos[(i + 1) % pos.shape[0], (j + 1) % pos.shape[1]] == 1: # up-right
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[2]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[3]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[4]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []


for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[5]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[6]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[7]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
R_factor = int(Rs[8]*8) # Number of neighbours to be unhappy enough to move

pos = np.zeros((N**2, 1))
pos[:int(np.ceil((1-ratio)*N**2))] = 1
np.random.shuffle(pos)
pos = pos.reshape(N, N)
mov = np.zeros((N, N))

pos_array = []
mov_array = []

for p in range(Range):
    mov = unhappy_agents(pos, R_factor)
    pos_array.append(pos.copy())
    mov_array.append(mov.copy())
    for i in range(mov.shape[0]):
        for j in range(mov.shape[1]):
            if mov[i, j] == 1:
                N_moving[p,R_factor] += 1
                pos[i, j] = 0
                while k == 0: # Moving all agents
                    i_ = np.random.randint(pos.shape[0])
                    j_ = np.random.randint(pos.shape[1])
                    if pos[i_, j_] == 0:
                        k = 1       
                pos[i_, j_] = 1
                k = 0

# %%
fig = plt.figure(figsize = (14,11))
plt.rcParams.update({'font.size': 20})
im = plt.imshow(pos, vmin=0, vmax=1, cmap='gist_yarg')
title = plt.title('City map for R = %d' % R_factor)

def animate(i): # Animation 
    im.set_array(pos_array[i]) 

ani = animation.FuncAnimation(fig, animate, len(pos_array))

ani.save('City map for R = %d.gif' % R_factor)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
plt.figure(figsize = (14,11))   

for i in range(9):
    plt.plot(range(Range), N_moving[:,i], label = 'R_factor = %d' %i) 
    
plt.rcParams.update({'font.size': 20})
plt.yscale('log')
plt.legend(loc = 'best')
plt.title('C') 
plt.xlabel('Timestamps')
plt.ylabel('Number of moving agents')
plt.show()

# %%
plt.figure(figsize = (14,11))   

for i in range(9):
    plt.plot(range(Range), N_moving[:,i], label = 'R_factor = %d' %i) 
    
plt.rcParams.update({'font.size': 20})
plt.legend(loc = 'best')
plt.title('C') 
plt.xlabel('Timestamps')
plt.ylabel('Number of moving agents')
plt.show()
