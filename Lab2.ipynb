# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# %matplotlib inline

# %% [markdown]
# ## Exercise 1

# %%
# Definition of bifurcation function

def bifurcation(x, r):
    return(r * (1 - x) * x)

# %%
# Test for one particular r

Range = 101
r = 2.4
X = []
x = np.random.rand()

for n in range(Range):
    x = bifurcation(x, r)
    X.append(x)
plt.plot(range(Range), X, '.')
plt.xlabel('N')
plt.ylabel('x')
plt.show()

# %%
# As we can see, with r-value between 2 and 3 everything is diverges (so we kind of played with r)

plt.figure(figsize=(10,10))
Range = 101
r = 2.5
x = np.random.rand()

for i in range(9):
    X = []
    for n in range(Range):
        x = bifurcation(x, r)
        X.append(x)
    r = r + 0.1
    plt.plot(range(Range), X, '.', label = 'r = %.1f' % r)


plt.legend(loc='best')
plt.xlabel('N')
plt.ylabel('x')
plt.show()

# %%
# Here we can observe bifurcation with 200 elements of our X_n left
from time import time

Range = 1001
plt.figure(figsize = (16,9))
r = np.linspace(1,4,Range)
X =[]
x = np.random.rand()*np.ones(Range)
Time_array = []
for n in range(Range):
    start_time = time()
    x = bifurcation(x, r)
    if n > (Range - 200): plt.plot(r, x, 'm.') # restriction for last 200 elements and plotting
    np.append(Time_array, time() - start_time)
plt.title('Bifurcation map')
plt.xlabel('r')
plt.ylabel('x')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-22b6f07a42bb> in <module>
#      10 for n in range(Range):
#      11     start_time = time()
# ---> 12     x = bifurcation(x, r)
#      13     if n > (Range - 200): plt.plot(r, x, 'm.') # restriction for last 200 elements and plotting
#      14     np.append(Time_array, time() - start_time)
#
# NameError: name 'bifurcation' is not defined

# %%
plt.plot(range(Range), Time_array, '.-', markersize=12)

# %%
def repeat_function(x,r, repetitions = 10000):
    for _ in range(repetitions):
         x = bifurcation(x, r)

# %%
from time import time
import cProfile
Range = 1001


r = np.linspace(1,4,Range)
X =[]
x = np.random.rand()*np.ones(Range)
Time_array = []

cProfile.run('repeat_function(   x = ' + str(x) + ',' +
                                'r = ' + str(r)+     ')' )
# Out:
#          2 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# Traceback (most recent call last):
#
#   File "/home/alexh3/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-7e0f4ff03a53>", line 12, in <module>
#     'r = ' + str(r)+     ')' )
#
#   File "/home/alexh3/anaconda3/lib/python3.7/cProfile.py", line 16, in run
#     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
#   File "/home/alexh3/anaconda3/lib/python3.7/profile.py", line 53, in run
#     prof.run(statement)
#
#   File "/home/alexh3/anaconda3/lib/python3.7/cProfile.py", line 95, in run
#     return self.runctx(cmd, dict, dict)
#
#   File "/home/alexh3/anaconda3/lib/python3.7/cProfile.py", line 100, in runctx
#     exec(cmd, globals, locals)
#
#   File "<string>", line 1
#     repeat_function(   x = [0.47635552 0.47635552 0.47635552 ... 0.47635552 0.47635552 0.47635552],r = [1.    1.003 1.006 ... 3.994 3.997 4.   ])
#                                                 ^
# SyntaxError: invalid syntax

# %%
plt.plot(range(Range), Time_array, '.-', markersize=12)

# %%
import mpi4py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-0fda0b379bd9> in <module>
# ----> 1 import mpi4py
#
# ModuleNotFoundError: No module named 'mpi4py'
